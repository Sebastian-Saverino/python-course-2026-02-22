# %%
# Student Code Review

# List of weekdays
# Lists in Python are zero-indexed, meaning counting starts at 0.
# So:
# "Sunday" = 0
# "Monday" = 1
# "Tuesday" = 2
# "Wednesday" = 3
# "Thursday" = 4
# "Friday" = 5
# "Saturday" = 6

weekdays = [
    'Sunday',
    'Monday',
    'Tuesday',
    'Wednesday',
    'Thursday',
    'Friday',
    'Saturday'
]

# The current day of the week that I chose
today = 'Saturday'

# A day of the week that I wish it was, but it is not
wish_it_was = 'Tuesday'


# Step 1: Find the index of "today"
# .index() searches through the list and returns
# the numeric position of the value inside the list.
#
# Example:
# weekdays.index("Friday") would return 5
#
# This value is already an integer, so we do not need to cast it with int().

today_index = weekdays.index(today)

# Step 2: Determine tomorrow
# If today's index is less than 6 (not Saturday),
# then tomorrow is simply the next position in the list.
#
# Since lists are zero-based:
# If today_index = 5 (Friday),
# then tomorrow would be at index 6 (Saturday).
#
# HOWEVER:
# If today_index = 6 (Saturday),
# we cannot add 1 because that would cause an IndexError.
# There is no index 7 in this list.
#
# So in that case, we wrap around back to index 0 (Sunday).

if today_index < 6:
    tomorrow = weekdays[today_index + 1]
else:
    tomorrow = weekdays[0]

# Step 3: Build the sentence
# The f in front of the string stands for "formatted string literal".
# It allows us to insert variables directly inside the string
# using curly braces {}.
#
# {today} will be replaced with the value of today.
# {tomorrow} will be replaced with the value of tomorrow.
# {wish_it_was} will be replaced with the value of wish_it_was.

sentence = f"Today is {today}. Tomorrow is {tomorrow}. I wish it was always {wish_it_was}."
# Step 4: Print the final result
# print() outputs the final formatted string to the console.

print(sentence)
# Out:
# Today is Saturday. Tomorrow is Sunday. I wish it was always Tuesday.

# %%
weekdays = [
    'Sunday', 'Monday', 'Tuesday',
    'Wednesday', 'Thursday', 'Friday', 'Saturday'
]

# Current day
today = input("What day is it today? ")

# if today not in weekdays:
#     raise ValueError(
#         f"Invalid day provided: '{today}'. "
#         "Please choose a real weekday you goofball."
#     )


if today in weekdays:
    print(f"Great! '{today}' is a valid weekday.")
else:
    print(f"'{today}' is not a valid weekday. Please enter a real day of the week.")
    today = input("Try again: What day is it today? ")

# try:
#     today_index = weekdays.index(today)
# except ValueError:
#     print("The day you entered does not exist in the weekdays list.")

# Day you wish it was
wish_it_was = 'Funday Monday :)'

# Get the index of today
today_index = weekdays.index(today)

# Determine tomorrow
if today_index < 6:
    tomorrow = weekdays[today_index + 1]
else:
    # If today is Saturday (index 6), wrap around to Sunday
    tomorrow = weekdays[0]

# Create formatted sentence
sentence = (
    f"Today is {today}. "
    f"Tomorrow is {tomorrow}. "
    f"I wish it was always {wish_it_was}."
)

# Output result
print(sentence)
# Out:
# 'rawr' is not a valid weekday. Please enter a real day of the week.
# Today is Monday. Tomorrow is Tuesday. I wish it was always Funday Monday :).

# %%
#This is nested if statement example

weekdays = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

tomorrow = 'dead'
wish_it_was = 'Tuesday'


day = input('What day is today?')  
if day in weekdays:
    today = day
    if (int(weekdays.index(today))) < 6:
        tomorrow = weekdays[int(weekdays.index(today) + 1)]
    else:
        tomorrow = weekdays[0]
        
    the_sntnc = f'Today is {today}. Tomorrow is {tomorrow}. I wish it was always {wish_it_was}'
    print(the_sntnc)


else:
    print('nope')
``

# %% [markdown]
# # Modulo Time!!!!!
#
# ```python
# a % b
# ```
#
#
#
#  Divide `a` by `b`, then return what is left over.
#
#
# ## What is modulo used for?
#
# - Detect even vs odd numbers

# %%
# number = 3

ans_1 = 15 // 6
# print(ans_1)



number = 33145897432507342870

if number % 2 == 0:
    print("Even")
else:
    print("Odd")


ans_1

# %%
help("%")

# %%
numbers = [1, 2, 3, 4, 5]

squared = []
meow = 3 
for meow in numbers:
    squared.append(meow ** 2)

print(squared)

# %%
numbers = [1, 2, 3, 4, 5]



squared = [meow ** 2 for meow in numbers]
print(squared)

# %%
numbers = [1,2,3,4,5]
evens = []

for n in numbers:
    if n % 2 == 0:
        evens.append(n)


even = [x for x in numbers if x % 2 == 0]

# %%
first = ['Work it','Make it','Do it','Makes us']
second = ['Harder','Better','Faster','Stronger']

meow = zip(first, second)

# print(list(meow))
# meow_1 = [x[1] for x in zip(first, second)]
# print(meow_1)

lyric = {x[0]:x[1] for x in meow}
print(lyric)
# Out:
# {'Work it': 'Harder', 'Make it': 'Better', 'Do it': 'Faster', 'Makes us': 'Stronger'}
