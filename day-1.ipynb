# %% [markdown]
# # We love markdown
#
#
# ## Data
#
# ### Assignment
# - rawr = 0
#
# ### Equalities
# - `==` — Equal to — `5 == 5`
# - `!=` — Not equal to - `5 != 3`
# - `>` — Greater than — `10 > 3`
# - `<` — Less than — `2 < 1` →
# - `>=` — Greater than or equal to — `5 >= 5` →
# - `<=` — Less than or equal to — `4 <= 3` →
#
# ### Data types
# - bool(True)
# - float(3.141)
# - int(5000)
# - str("string")
# - meow = None
# - complex = 2 + 3y
# - type(1) #Tells us the type
# - bytes = bytes are lowkey op as the computer is a dawg as reading bytes
# - b = b"ABC"
# - print(b)

# %%
var_1 = "fun"
print(var_1)
# Out:
# fun

# %%
#This is a note!
#Syntax = code structure
