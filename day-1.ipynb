# %% [markdown]
# # We love markdown
#
#
# ## Data
#
# ### Assignment
# - rawr = 0
#
# ### Equalities
# - `==` — Equal to — `5 == 5`
# - `!=` — Not equal to - `5 != 3`
# - `>` — Greater than — `10 > 3`
# - `<` — Less than — `2 < 1`
# - `>=` — Greater than or equal to — `5 >= 5`
# - `<=` — Less than or equal to — `4 <= 3`
#
# ### Data types
# - bool(True)
# - float(3.141)
# - int(5000)
# - str("string")
# - meow = None
# - complex = 2 + 3y
# - type(1) #Tells us the type
# - bytes = bytes are lowkey op as the computer is a dawg as reading bytes
# - b = b"ABC"
# - print(b)
#
# ### Data Sequences
# my_list =
# my_tuple =
# my_set =
# my

# %%
var_1 = "fun"
print(var_1)
# Out:
# fun

# %%
#This is a note!
#Syntax = code structure

# %%
checking = list([1,3.3,False,"clown"])
checking[0] #Indexing - Gives us the first number in the list (0 spot) 
checking[1:3] #Slicing - Begins at 1 spot and stop at the 3 spot
# print(checking) #Provides the entire list
checking[:] #Provides the entire list
my_dict = {
    'cookies':'dessert',
    'hummus':'condiemnt'
}
my_dict #calls your dictionary
my_dict["cookies"]
for i in my_dict:
    print(my_dict.keys)
# Out:
# <built-in method keys of dict object at 0x000001C8DCA17A40>
# <built-in method keys of dict object at 0x000001C8DCA17A40>
