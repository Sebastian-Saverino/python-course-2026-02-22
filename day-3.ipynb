# %% [markdown]
# start:	Optional. An integer number specifying at which position to start. Default is 0
# stop:	Required. An integer number specifying at which position to stop (not included).
# step:	Optional. An integer number specifying the incrementation. Default is 1

# %%
for x in range(1,101):
    if x % 15 == 0:
        print("FizzBuzz")
    elif x % 3 == 0:
        print("Fizz")
    elif x % 5 == 0:
        print("Buzz")
    else:
        print(x)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# # Function Time!

# %%
def tax_calculator(price, tax_rate):
    total = price + (price * tax_rate)
    return total

tax_calculator(1000000,.2)
var = 1

# %%
def bill_splitter(bill,tip_percent,split_by):
    tip_amount = bill * (tip_percent / 100)
    total_amount = bill + tip_amount
    per_person = total_amount / split_by
    return per_person


print(f"Each person should pay: ${bill_splitter(100, 15, 4):.2f}")

# %%
def plan_trip():
    # First we want to get the inputs
    destination = input("Enter your where you want to go: ")
    hotel_price_per_night = float(input("Enter hotel price per night: "))
    length_of_stay = int(input("Enter length of stay (nights): "))
    discount_percent = float(input("Enter discount percentage: "))

    # Calculate total before discount
    total_cost = hotel_price_per_night * length_of_stay

    # Calculate discount
    discount_amount = total_cost * (discount_percent / 100)

    # Final cost
    final_cost = total_cost - discount_amount

    # Print summary
    print("\nTrip Summary")
    print(f"Destination: {destination}")
    print(f"Length of Stay: {length_of_stay} nights")
    print(f"Hotel Price Per Night: ${hotel_price_per_night:.2f}")
    print(f"Discount Applied: {discount_percent}%")
    print(f"Total Trip Cost: ${final_cost:.2f}")


plan_trip()
# Out:
# Trip Summary
# Destination: Home
# Length of Stay: 3 nights
# Hotel Price Per Night: $3.00
# Discount Applied: 3.0%
# Total Trip Cost: $8.73

# %% [markdown]
# Clean, organized list — Python format specifiers (used in **f-strings** and `str.format()`).
#
# #  Basic Format Specifiers
#
# | Specifier | Meaning                         | Example       | Output         |
# | --------- | ------------------------------- | ------------- | -------------- |
# | `s`       | String                          | `f"{name:s}"` | `"Sebastian"`  |
# | `d`       | Integer (decimal)               | `f"{5:d}"`    | `5`            |
# | `f`       | Float                           | `f"{3.14:f}"` | `3.140000`     |
# | `e`       | Scientific notation (lowercase) | `f"{1000:e}"` | `1.000000e+03` |
# | `E`       | Scientific notation (uppercase) | `f"{1000:E}"` | `1.000000E+03` |
# | `g`       | General format                  | `f"{1000:g}"` | `1000`         |
# | `G`       | General (uppercase)             | `f"{1000:G}"` | `1000`         |
# | `%`       | Percentage                      | `f"{0.25:%}"` | `25.000000%`   |
#
# ---
#
# # Precision Control
#
# Control decimal places with `.N`
#
# ```python
# f"{3.14159:.2f}"
# ```
#
# Output:
#
# ```
# 3.14
# ```
#
# | Format | Meaning               |
# | ------ | --------------------- |
# | `.2f`  | 2 decimal places      |
# | `.3f`  | 3 decimal places      |
# | `.0f`  | No decimals (rounded) |
#
#
# #  Width & Alignment
#
# | Syntax | Meaning      | Example      | Output         |
# | ------ | ------------ | ------------ | -------------- |
# | `:10`  | Width of 10  | `f"{5:10}"`  | `'         5'` |
# | `:<10` | Left align   | `f"{5:<10}"` | `'5         '` |
# | `:>10` | Right align  | `f"{5:>10}"` | `'         5'` |
# | `:^10` | Center align | `f"{5:^10}"` | `'    5     '` |
#
#
#
# # Padding
#
# ```python
# f"{5:05}"
# ```
#
# Output:
#
# ```
# 00005
# ```
#
# | Format  | Meaning              |
# | ------- | -------------------- |
# | `:05`   | Pad with zeros       |
# | `:_>10` | Pad with `_` on left |
# | `:*^10` | Center with `*`      |
#
#
#
# # 🔹 Thousands Separator
#
# ```python
# f"{1000000:,}"
# ```
#
# Output:
#
# ```
# 1,000,000
# ```
#
# Also:
#
# ```python
# f"{1000000:_}"
# ```
#
# Output:
#
# ```
# 1_000_000
# ```
#
# ---
#
# # Currency Style
#
# ```python
# price = 1234.5
# f"${price:,.2f}"
# ```
#
# Output:
#
# ```
# $1,234.50
# ```
#
# This is the professional finance formatting.
#
# ---
#
# # Sign Control
#
# | Format | Meaning            | Example |
# | ------ | ------------------ | ------- |
# | `:+`   | Always show sign   | `+5`    |
# | `:-`   | Only negative sign | `-5`    |
# | `: `   | Space for positive | `' 5'`  |
#
# Example:
#
# ```python
# f"{5:+}"
# ```
#
# Output:
#
# ```
# +5
# ```
